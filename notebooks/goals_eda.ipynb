# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/processed/data_with_odds.csv")

# %%
df
# Out:
#                name_player position_player     team_player  assists_player  \
# 0           Aaron Connolly             FWD        Brighton               0
# 1               Aaron Mooy             MID        Brighton               0
# 2             Adam Lallana             MID        Brighton               0
# 3             Adam Webster             DEF        Brighton               0
# 4      Alexis Mac Allister             MID        Brighton               0
# ...                    ...             ...             ...             ...
# 68413          Scott Banks             MID  Crystal Palace               0
# 68414      Tyrick Mitchell             DEF  Crystal Palace               0
# 68415       Vicente Guaita              GK  Crystal Palace               0
# 68416        Wilfried Zaha             MID  Crystal Palace               0
# 68417          Will Hughes             MID  Crystal Palace               0
#
# ...

# %%
df.columns[:36]
# Out:
# Index(['name_player', 'position_player', 'team_player', 'assists_player',
#        'bonus_player', 'bps_player', 'clean_sheets_player',
#        'creativity_player', 'fixture_player', 'goals_conceded_player',
#        'goals_scored_player', 'ict_index_player', 'influence_player',
#        'kickoff_time', 'minutes_player', 'own_goals_player',
#        'penalties_missed_player', 'penalties_saved_player', 'red_cards_player',
#        'saves_player', 'selected_player', 'threat_player',
#        'total_points_player', 'transfers_balance_player',
#        'transfers_in_player', 'transfers_out_player', 'value_player',
#        'was_home_player', 'yellow_cards_player', 'season', 'opponent_team',
#        'fixture_id_player', 'team_season_goals_scored',
#        'team_season_goals_against', 'last_10_team_match_points',
#        'last_10_team_goals'],
#       dtype='object')
